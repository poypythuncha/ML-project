# %%
pip install opencv-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
! wget https://github.com/poypythuncha/ML-project/blob/main/Image_front_door/frontImage.zip
# Out:
# --2022-09-03 13:00:57--  https://github.com/poypythuncha/ML-project/blob/main/Image_front_door/frontImage.zip
# Resolving github.com (github.com)... 20.205.243.166
# Connecting to github.com (github.com)|20.205.243.166|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: 'frontImage.zip'
#
# frontImage.zip          [ <=>                ] 127.06K  --.-KB/s    in 0.1s
#
# 2022-09-03 13:00:58 (1.06 MB/s) - 'frontImage.zip' saved [130105]

# %%
path = "fronImage.zip"
import zipfile
with zipfile.ZipFile(path, 'r') as zip_ref:
    zip_ref.extractall(directory_to_extract_to)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /Users/zoonyanapat/Documents/Coding_Time/Python/ML-project/ML_project_9.2.2022.ipynb Cell 3 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/Users/zoonyanapat/Documents/Coding_Time/Python/ML-project/ML_project_9.2.2022.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> path = "fronImage.zip"
#       <a href='vscode-notebook-cell:/Users/zoonyanapat/Documents/Coding_Time/Python/ML-project/ML_project_9.2.2022.ipynb#X10sZmlsZQ%3D%3D?line=1'>2</a> import zipfile
# ----> <a href='vscode-notebook-cell:/Users/zoonyanapat/Documents/Coding_Time/Python/ML-project/ML_project_9.2.2022.ipynb#X10sZmlsZQ%3D%3D?line=2'>3</a> with zipfile.ZipFile(path, 'r') as zip_ref:
# ...

# %%
#load images
#import glob
#from IPython.display import Image, display
#for imageName in glob.glob('/Users/poypythuncha/Documents/STUDY/MS_TS_Chula/Image_front_door/*.jpg'): #assuming JPG
    #display(Image(filename=imageName))
    #print(imageName)
    
from PIL import Image
import glob
image_list = []
for filename in glob.glob('/Users/poypythuncha/Documents/STUDY/MS_TS_Chula/Image_front_door/*.jpeg'): #assuming gif
    im=Image.open(filename)
    image_list.append(im)

# %%
import pandas as pd

# %%
image_list[0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /Users/zoonyanapat/Documents/Coding_Time/Python/ML-project/ML_project_9.2.2022.ipynb Cell 4 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/zoonyanapat/Documents/Coding_Time/Python/ML-project/ML_project_9.2.2022.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> image_list[0]
#
# IndexError: list index out of range

# %%
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-15-cc0bc9f62a77> in <module>
#       1 import matplotlib.pyplot as plt
#       2 import matplotlib.image as mpimg
# ----> 3 img = mpimg.imread('image_list.jpeg')
#       4 imgplot = plt.imshow(img)
#       5 plt.show()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/image.py in imread(fname, format)
#    1494                     response = io.BytesIO(response.read())
#    1495                 return imread(response, format=ext)
# -> 1496     with img_open(fname) as image:
#    1497         return (_pil_png_to_float_array(image)
#    1498                 if isinstance(image, PIL.PngImagePlugin.PngImageFile) else
#
# ~/opt/anaconda3/lib/python3.8/site-packages/PIL/Image.py in open(fp, mode, formats)
#    2910
#    2911     if filename:
# -> 2912         fp = builtins.open(filename, "rb")
# ...
